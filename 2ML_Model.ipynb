# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings 
# %matplotlib inline 
warnings.filterwarnings('ignore')

# %%
import sklearn

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/MobilePriceRange.csv')

# %%
df.head()
# Out:
#    BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0           842               7         2.2          2  2549        19
# 1          1021              53         0.5          3  2631         7
# 2           563              41         0.5          5  2603         9
# 3           615              10         2.5          6  2769        11
# 4          1821              44         1.2          2  1411        15
#
#    DualSim  3G  4G  WiFi  ...  MobileDepth  MobileWeight  TouchScreen  \
# 0        0   0   0     1  ...          0.6           188            0
# 1        1   1   1     0  ...          0.7           136            1
# 2        1   1   1     0  ...          0.9           145            1
# 3        0   1   0     0  ...          0.8           131            0
# 4        0   1   1     0  ...          0.6           141            1
#
#    ScreenHeight  ScreenWidth  FrontCameraPx  RearCameraPX  PxHeight  PxWeight  \
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BatteryPower    2000 non-null   int64
#  1   InternalMemory  2000 non-null   int64
#  2   ClockSpeed      2000 non-null   float64
#  3   NoOfCores       2000 non-null   int64
#  4   RAM             2000 non-null   int64
#  5   TalkTime        2000 non-null   int64
#  6   DualSim         2000 non-null   int64
#  7   3G              2000 non-null   int64
#  8   4G              2000 non-null   int64
#  9   WiFi            2000 non-null   int64
#  10  Bluetooth       2000 non-null   int64
#  11  MobileDepth     2000 non-null   float64
#  12  MobileWeight    2000 non-null   int64
#  13  TouchScreen     2000 non-null   int64
#  14  ScreenHeight    2000 non-null   int64
#  15  ScreenWidth     2000 non-null   int64
#  16  FrontCameraPx   2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        BatteryPower  InternalMemory   ClockSpeed    NoOfCores          RAM  \
# count   2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean    1238.518500       32.046500     1.522250     4.520500  2124.213000
# std      439.418206       18.145715     0.816004     2.287837  1084.732044
# min      501.000000        2.000000     0.500000     1.000000   256.000000
# 25%      851.750000       16.000000     0.700000     3.000000  1207.500000
# 50%     1226.000000       32.000000     1.500000     4.000000  2146.500000
# 75%     1615.250000       48.000000     2.200000     7.000000  3064.500000
# max     1998.000000       64.000000     3.000000     8.000000  3998.000000
#
#           TalkTime      DualSim           3G           4G         WiFi  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     11.011000     0.509500     0.761500     0.521500     0.507000
# std       5.463955     0.500035     0.426273     0.499662     0.500076
# ...

# %%
df.isnull().sum()
# Out:
# BatteryPower      0
# InternalMemory    0
# ClockSpeed        0
# NoOfCores         0
# RAM               0
# TalkTime          0
# DualSim           0
# 3G                0
# 4G                0
# WiFi              0
# Bluetooth         0
# MobileDepth       0
# MobileWeight      0
# TouchScreen       0
# ScreenHeight      0
# ScreenWidth       0
# FrontCameraPx     0
# RearCameraPX      0
# PxHeight          0
# PxWeight          0
# PriceRange        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['BatteryPower', 'InternalMemory', 'ClockSpeed', 'NoOfCores', 'RAM',
#        'TalkTime', 'DualSim', '3G', '4G', 'WiFi', 'Bluetooth', 'MobileDepth',
#        'MobileWeight', 'TouchScreen', 'ScreenHeight', 'ScreenWidth',
#        'FrontCameraPx', 'RearCameraPX', 'PxHeight', 'PxWeight', 'PriceRange'],
#       dtype='object')

# %%
df['WiFi'].value_counts()
# Out:
# 1    1014
# 0     986
# Name: WiFi, dtype: int64

# %%
df['PriceRange'].value_counts()
# Out:
# Medium      500
# High        500
# VeryHigh    500
# Low         500
# Name: PriceRange, dtype: int64

# %%
df['PriceRange'] = df['PriceRange'].map({'Low' : 0 , 'Medium' : 1 , 'High' : 2 , 'VeryHigh' : 3 })

# %%
df.head(2)
# Out:
#    BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0           842               7         2.2          2  2549        19
# 1          1021              53         0.5          3  2631         7
#
#    DualSim  3G  4G  WiFi  ...  MobileDepth  MobileWeight  TouchScreen  \
# 0        0   0   0     1  ...          0.6           188            0
# 1        1   1   1     0  ...          0.7           136            1
#
#    ScreenHeight  ScreenWidth  FrontCameraPx  RearCameraPX  PxHeight  PxWeight  \
# 0             9            7              1             2        20       756
# 1            17            3              0             6       905      1988
#
#    PriceRange
# 0           1
# 1           2
#
# [2 rows x 21 columns]

# %%
df['PriceRange'].dtype
# Out:
# dtype('int64')

# %%
plt.figure(figsize=(15,10))

for id,column in enumerate(df.columns):
    plt.subplot(5,5,id+1)
    sns.histplot(data=df,x=column,kde=True,hue='PriceRange')
    
    plt.tight_layout()

# %%
df['MobileDepth'].value_counts()
# Out:
# 0.1    320
# 0.2    213
# 0.8    208
# 0.5    205
# 0.7    200
# 0.3    199
# 0.9    195
# 0.6    186
# 0.4    168
# 1.0    106
# Name: MobileDepth, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['PriceRange'],axis=1)

# %%
x
# Out:
#       BatteryPower  InternalMemory  ClockSpeed  NoOfCores   RAM  TalkTime  \
# 0              842               7         2.2          2  2549        19
# 1             1021              53         0.5          3  2631         7
# 2              563              41         0.5          5  2603         9
# 3              615              10         2.5          6  2769        11
# 4             1821              44         1.2          2  1411        15
# ...            ...             ...         ...        ...   ...       ...
# 1995           794               2         0.5          6   668        19
# 1996          1965              39         2.6          4  2032        16
# 1997          1911              36         0.9          8  3057         5
# 1998          1512              46         0.9          5   869        19
# 1999           510              45         2.0          6  3919         2
#
#       DualSim  3G  4G  WiFi  Bluetooth  MobileDepth  MobileWeight  \
# ...

# %%
y = df['PriceRange']

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: PriceRange, Length: 2000, dtype: int64

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y,random_state=100)

# %%
x_train.shape, x_test.shape,y_train.shape , y_test.shape
# Out:
# ((1500, 20), (500, 20), (1500,), (500,))

# %%
#Standard scaling
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %% [markdown]
# # LogisticRegression Model

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.954

# %%
lr.coef_
# Out:
# array([[-2.63683573e+00, -1.84476172e-01,  9.82400996e-02,
#         -2.78373644e-02, -1.06373817e+01, -8.00705640e-02,
#          6.87102240e-02, -6.18141667e-02,  7.39406871e-02,
#          9.00875509e-02, -2.35423830e-04,  1.31899893e-01,
#          2.94678261e-01,  5.24494859e-02,  4.56164735e-02,
#         -2.10137182e-02, -8.65598601e-02,  9.75941888e-03,
#         -1.65975924e+00, -1.46306159e+00],
#        [-8.49375124e-01, -3.64657076e-02,  1.93736685e-02,
#         -1.29799598e-01, -3.41481438e+00, -3.32131022e-02,
#          7.68420829e-02,  1.84627128e-02,  2.50109418e-02,
#          1.86936831e-02, -5.47714136e-02,  1.21251997e-01,
#          1.35233282e-01,  2.54403387e-02, -6.01549093e-02,
#         -7.73046341e-02, -6.37729213e-03, -5.84045066e-03,
#         -5.18634914e-01, -4.98729168e-01],
#        [ 7.89974139e-01,  4.13107379e-03, -5.97137256e-02,
#          5.39229195e-02,  3.40605727e+00,  4.76612048e-02,
# ...

# %%
lr.intercept_
# Out:
# array([-3.33600594,  3.03683782,  3.1585701 , -2.85940198])

# %%
y_pred = lr.predict(x_test)

y_pred
# Out:
# array([0, 2, 1, 3, 2, 3, 3, 2, 3, 0, 0, 2, 3, 3, 0, 2, 2, 3, 2, 0, 0, 3,
#        1, 0, 0, 1, 3, 0, 2, 2, 0, 3, 0, 1, 0, 3, 3, 2, 1, 3, 3, 3, 0, 0,
#        3, 3, 2, 0, 1, 2, 3, 2, 3, 2, 1, 3, 1, 3, 1, 0, 3, 2, 3, 0, 2, 0,
#        0, 3, 3, 2, 0, 0, 2, 1, 2, 3, 0, 3, 2, 3, 1, 0, 2, 0, 2, 2, 1, 2,
#        3, 3, 2, 3, 3, 2, 0, 2, 3, 1, 1, 1, 0, 0, 3, 3, 2, 0, 0, 1, 0, 1,
#        1, 1, 3, 2, 0, 3, 1, 3, 1, 1, 2, 1, 0, 1, 3, 2, 3, 2, 0, 3, 2, 0,
#        1, 2, 3, 1, 3, 2, 0, 1, 3, 0, 2, 3, 1, 2, 2, 2, 0, 1, 0, 3, 2, 2,
#        1, 0, 2, 3, 1, 1, 3, 2, 3, 0, 0, 3, 0, 2, 3, 0, 2, 0, 2, 1, 1, 2,
#        2, 1, 3, 1, 0, 2, 1, 0, 0, 3, 2, 2, 3, 2, 2, 1, 2, 1, 2, 2, 3, 1,
#        2, 1, 3, 1, 2, 1, 3, 0, 2, 3, 3, 2, 0, 1, 2, 0, 1, 2, 3, 0, 1, 3,
#        0, 3, 0, 0, 1, 2, 2, 3, 2, 0, 2, 2, 0, 1, 1, 3, 2, 3, 2, 0, 1, 3,
#        1, 1, 0, 2, 3, 1, 1, 1, 1, 2, 3, 1, 3, 2, 1, 1, 2, 3, 1, 3, 2, 2,
#        2, 2, 3, 1, 2, 1, 1, 3, 2, 0, 2, 1, 1, 3, 2, 2, 2, 1, 3, 1, 0, 2,
# ...

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.954

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.99      0.99       135\n           1       0.95      0.91      0.93       123\n           2       0.90      0.93      0.92       118\n           3       0.98      0.98      0.98       124\n\n    accuracy                           0.95       500\n   macro avg       0.95      0.95      0.95       500\nweighted avg       0.95      0.95      0.95       500\n'

# %%
plt.scatter(y_test,y_pred)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[134,   1,   0,   0],
#        [  2, 112,   9,   0],
#        [  0,   5, 110,   3],
#        [  0,   0,   3, 121]], dtype=int64)

# %% [markdown]
# # RandomForestClassifier Model

# %%
from sklearn.ensemble import RandomForestClassifier
rfl = RandomForestClassifier()

# %%
rfl.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_chat = rfl.predict(x_test)

# %%
rfl.score(x_train,y_train)
# Out:
# 1.0

# %%
accuracy_score(y_test,y_chat)
# Out:
# 0.882

# %%
classification_report(y_test,y_chat)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.93      0.95      0.94       135\n           1       0.81      0.84      0.82       123\n           2       0.83      0.80      0.81       118\n           3       0.94      0.94      0.94       124\n\n    accuracy                           0.88       500\n   macro avg       0.88      0.88      0.88       500\nweighted avg       0.88      0.88      0.88       500\n'

# %%
plt.scatter(y_test,y_chat)
