# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Big%20Sales%20Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11815 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11815.000000     14204.000000  14204.000000               14204.000000
# mean      12.788355         0.065953    141.004977                1997.830681
# std        4.654126         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.500000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       30.000000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count       14204.000000
# mean         2185.836320
# std          1827.479550
# min            33.290000
# 25%           922.135101
# 50%          1768.287680
# 75%          2988.110400
# max         31224.726950

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
# 2           FDT36         12.3               LF         0.111728
# 3           FDT36         12.3          Low Fat         0.000000
# 4           FDP12          9.8          Regular         0.045523
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
# 2  Baking Goods   33.9874            OUT018                       2009
# 3  Baking Goods   34.3874            OUT019                       1985
# 4  Baking Goods   35.0874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# ...

# %%
df.shape
# Out:
# (14204, 12)

# %%
df['Item_Type'].unique()
# Out:
# array(['Baking Goods', 'Breads', 'Breakfast', 'Canned', 'Dairy',
#        'Frozen Foods', 'Fruits and Vegetables', 'Hard Drinks',
#        'Health and Hygiene', 'Household', 'Meat', 'Others', 'Seafood',
#        'Snack Foods', 'Soft Drinks', 'Starchy Foods'], dtype=object)

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'LF', 'Regular', 'reg', 'low fat'], dtype=object)

# %%
plt.figure(figsize=(12,6))
df['Item_Type'].value_counts().plot(kind='barh')
plt.show()

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDT36    10
# FDG09    10
# FDZ56    10
# FDT19    10
# FDD56    10
#          ..
# NCW54     7
# FDS22     7
# FDM50     7
# FDX49     7
# DRN11     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# 1      Medium               Tier 2  Supermarket Type1         443.127721

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,y='Item_MRP',x='Outlet_Establishment_Year',hue='Outlet_Size')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=df,x='Outlet_Type',hue='Item_Fat_Content')
plt.title('Type of Outlet')
plt.show()

# %%
sns.pairplot(df)

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# 1      Medium               Tier 2  Supermarket Type1         443.127721

# %%
pd.DataFrame(df.groupby(['Outlet_Establishment_Year']).mean()['Item_Outlet_Sales'].sort_values(ascending=False))
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1985                             2862.233438
# 2004                             2228.548893
# 2007                             2193.306963
# 1999                             2187.443408
# 1987                             2133.303083
# 1997                             2132.964978
# 2002                             2110.022471
# 2009                             1971.810671
# 1998                              976.996255

# %%
pd.DataFrame(df.groupby(['Outlet_Establishment_Year']).mean()['Item_Outlet_Sales'].sort_values(ascending=False)).plot(kind='barh',color='c',figsize=(15,6))
plt.title('Average outlet price by year')
plt.show()

# %%
corr_ = df.corr()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=corr_,annot=True,fmt='1.02f')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11815 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2389
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].value_counts()
# Out:
# 17.600    135
# 12.150    127
# 10.500    123
# 13.650    115
# 11.800    114
#          ...
# 8.485       7
# 4.615       6
# 9.035       6
# 7.850       6
# 30.000      1
# Name: Item_Weight, Length: 416, dtype: int64

# %%
mean_weight = df['Item_Weight'].mean()

# %%
df.fillna(mean_weight,inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df['Item_Weight'] = df['Item_Weight'].astype('int64')

# %%
df['Item_Weight'].value_counts()
# Out:
# 12    3175
# 7      923
# 8      845
# 6      834
# 15     827
# 9      807
# 17     751
# 10     737
# 16     722
# 20     715
# 19     676
# 11     639
# 13     634
# 18     613
# 5      567
# 14     558
# 21     105
# 4       75
# 30       1
# Name: Item_Weight, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  int64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1.3+ MB

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36           12          Low Fat         0.111448
# 1           FDT36           12          Low Fat         0.111904
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# 1      Medium               Tier 2  Supermarket Type1         443.127721

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
x = df[['Item_Weight','Item_Visibility','Item_MRP']]
x
# Out:
#        Item_Weight  Item_Visibility  Item_MRP
# 0               12         0.111448   33.4874
# 1               12         0.111904   33.9874
# 2               12         0.111728   33.9874
# 3               12         0.000000   34.3874
# 4                9         0.045523   35.0874
# ...            ...              ...       ...
# 14199           12         0.069606  261.9252
# 14200           12         0.070013  262.8252
# 14201           12         0.069561  263.0252
# 14202           12         0.069282  263.5252
# 14203           12         0.069727  263.6252
#
# [14204 rows x 3 columns]

# %%
y = df['Item_Outlet_Sales']
y
# Out:
# 0         436.608721
# 1         443.127721
# 2         564.598400
# 3        1719.370000
# 4         352.874000
#             ...
# 14199    4984.178800
# 14200    2885.577200
# 14201    2885.577200
# 14202    3803.676434
# 14203    3644.354765
# Name: Item_Outlet_Sales, Length: 14204, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20, random_state=15)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((11363, 3), (2841, 3), (11363,), (2841,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.3254674222067596

# %%
model.coef_
# Out:
# array([   56.49215949, -5426.29257616,    15.33400518])

# %%
model.intercept_
# Out:
# -314.26879769631296

# %%
predi_ = model.predict(x_test)

predi_
# Out:
# array([3508.4724284 , 3057.59897265, 1870.35231255, ..., 2057.66596104,
#        3102.5568976 , 1945.74504475])

# %%
residuals = y_test - predi_

residuals
# Out:
# 2462    -1180.169828
# 9580      647.578027
# 4716       51.146487
# 12207     862.736706
# 12653    -459.961633
#             ...
# 4587    -1516.056400
# 4979     -495.408298
# 12185     432.426039
# 12432   -1315.549698
# 9221     -137.432245
# Name: Item_Outlet_Sales, Length: 2841, dtype: float64

# %%
sns.displot(residuals,kind = 'kde')
